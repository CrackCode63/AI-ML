# %%
import pandas as pd
csv_1 = pd.read_csv("Data 1.csv")
csv_1
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
import pandas as pd
csv_1 = pd.read_csv("Data 1.csv",nrows = 3,usecols = ["Country","Age"])
# This can be written as:
csv_1 = pd.read_csv("Data 1.csv",nrows = 3,usecols = [0,2])
csv_1
# Out:
#    Country  Salary
# 0   France   72000
# 1    Spain   48000
# 2  Germany   54000

# %%
import pandas as pd
csv_1 = pd.read_csv("Data 1.csv",skiprows = [0,3])
csv_1
# Out:
#     France    44    72000   No
# 0    Spain  27.0  48000.0  Yes
# 1    Spain  38.0  61000.0   No
# 2  Germany  40.0      NaN  Yes
# 3   France  35.0  58000.0  Yes
# 4    Spain   NaN  52000.0   No
# 5   France  48.0  79000.0  Yes
# 6  Germany  50.0  83000.0   No
# 7   France  37.0  67000.0  Yes

# %%
csv_1[0:5:1]
start:stop+1:step

stop + 1 = 5
stop = 5 - 1
stop = 4
# Out:
#   Cell In[4], line 2
#     start:stop+1:step
#                 ^
# SyntaxError: invalid syntax

# %%
csv_1[0:5:1]
# Out:
#     France    44    72000   No
# 0    Spain  27.0  48000.0  Yes
# 1    Spain  38.0  61000.0   No
# 2  Germany  40.0      NaN  Yes
# 3   France  35.0  58000.0  Yes
# 4    Spain   NaN  52000.0   No

# %%
csv_1.columns
# Out:
# Index(['France', '44', '72000', 'No'], dtype='object')

# %%
csv_1.describe()
# Out:
#               44         72000
# count   7.000000      7.000000
# mean   39.285714  64000.000000
# std     7.825477  13165.611772
# min    27.000000  48000.000000
# 25%    36.000000  55000.000000
# 50%    38.000000  61000.000000
# 75%    44.000000  73000.000000
# max    50.000000  83000.000000

# %%
csv_1.head(3)
# Out:
#     France    44    72000   No
# 0    Spain  27.0  48000.0  Yes
# 1    Spain  38.0  61000.0   No
# 2  Germany  40.0      NaN  Yes

# %%
csv_1.tail(3)
# Out:
#     France    44    72000   No
# 5   France  48.0  79000.0  Yes
# 6  Germany  50.0  83000.0   No
# 7   France  37.0  67000.0  Yes

# %%
csv_1.loc[0,"Country"] = "python"
csv_1
# Out:
#     France    44    72000   No Country
# 0    Spain  27.0  48000.0  Yes  python
# 1    Spain  38.0  61000.0   No     NaN
# 2  Germany  40.0      NaN  Yes     NaN
# 3   France  35.0  58000.0  Yes     NaN
# 4    Spain   NaN  52000.0   No     NaN
# 5   France  48.0  79000.0  Yes     NaN
# 6  Germany  50.0  83000.0   No     NaN
# 7   France  37.0  67000.0  Yes     NaN

# %%
csv_1.loc[[2,4],["Country","Salary"]]
# Out:
#    Country   Salary
# 2  Germany  54000.0
# 4  Germany      NaN

# %%
csv_1.loc[[2,4],:]
# Out:
#     France    44    72000   No Country
# 2  Germany  40.0      NaN  Yes     NaN
# 4    Spain   NaN  52000.0   No     NaN

# %%
csv_1.iloc[0,1]
# Out:
# 27.0

# %%
csv_1.iloc[0:-1]
# Out:
#     France    44    72000   No Country
# 0    Spain  27.0  48000.0  Yes  python
# 1    Spain  38.0  61000.0   No     NaN
# 2  Germany  40.0      NaN  Yes     NaN
# 3   France  35.0  58000.0  Yes     NaN
# 4    Spain   NaN  52000.0   No     NaN
# 5   France  48.0  79000.0  Yes     NaN
# 6  Germany  50.0  83000.0   No     NaN
